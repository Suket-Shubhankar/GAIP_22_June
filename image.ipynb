# %% [markdown]
# <a href="https://colab.research.google.com/github/Suket-Shubhankar/GAIP_22_June/blob/main/image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
img = cv2.imread("/content/rick-morty.png")

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x675 at 0x7F877C8AAB10>

# %%
img = cv2.resize(img,(700,400))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=700x400 at 0x7F8786A07350>

# %%
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2XYZ)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=700x400 at 0x7F877AE52CD0>
